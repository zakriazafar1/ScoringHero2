# %% [markdown]
# # Spectogram file

# %%
import mne
raw = mne.io.read_raw_edf(r"T:\raw\bnbd\Data\eeg\NSR\bnbd_nsr_03554\bnbd_nsr_03554_T0_N1\sleepArchitecture\bnbd_nsr_03554_T0_N1_psg.edf", preload=False, verbose=False)
print(raw.ch_names)
# Out:
# ['EEG L psg-lp', 'EEG R psg-lp', 'EEG L psg-lp-hp', 'EEG R psg-lp-hp', 'EEG L psg-emg', 'EEG R psg-emg', 'dX', 'dY', 'dZ', 'OXY_IR_AC']
